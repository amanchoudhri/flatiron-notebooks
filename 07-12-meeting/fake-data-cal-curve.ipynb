# %% [markdown]
# # Calibration Curve on fake data
#
# Before looking into the calibration of MUSE for different smoothing methods, examine how the calibration curve function works for fake data.
#
# Define functions `uniform_samples`, `std_normal_samples`, and `skewed_normal_samples` to take in a positive integer `N`, and return `N` draws from their respective distributions.

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path

import numpy as np
from matplotlib import pyplot as plt
import scipy.stats
import h5py

import common
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
MIN_X, MAX_X = -8, 8
MIN_Y, MAX_Y = -8, 8

# generate fake data of different distributions
rng = np.random.default_rng(seed=2022)

# rescale to be on the square [-6, 6]^2 (arbitrarily chosen)
uniform_samples = lambda n_samples: (rng.uniform(size=(n_samples, 2)) * (MAX_X - MIN_X)) - MAX_X

std_normal_samples = lambda n_samples: rng.normal(size=(n_samples, 2))

SKEW_COV = [[2, -1], [-1, 2]]
skewed_normal_samples = lambda n_samples: rng.multivariate_normal(
    mean=[0, 0],
    cov=SKEW_COV,
    size=n_samples
)

# group each distr into one convenient function 
def observed_data(n_samples, add_noise=False, noise_std=0.1):
    """
    Automatically generate datasets given the number of samples and
    the desired noise parameters.
    """
    def gen_data(fn):
        """
        Given the args from the parent function, generate samples for
        each distribution of interest (e.g. uniform, spherical Gaussian, etc).
        """
        samples = fn(n_samples)
        if add_noise:
            # transform to the real line using a logit function
            k = MAX_X - MIN_X
            transformed = samples + MAX_X  # make each entry >= 0
            transformed = np.log( transformed / (k - transformed) )
            # add noise
            transformed += rng.normal(scale=noise_std, size=(n_samples, 2))
            # transform back to constrained interval
            samples = k / (1 + np.exp(-transformed))
            # recenter at 0
            samples -= MAX_X
        # clip values outside allowed range
        samples[:, 0] = samples[:, 0].clip(MIN_X, MAX_X)
        samples[:, 1] = samples[:, 1].clip(MIN_Y, MAX_Y)
        return samples

    return {
        'uniform': gen_data(uniform_samples),
        'std_normal': gen_data(std_normal_samples),
        'skew_normal': gen_data(skewed_normal_samples),
    }

# for now, use a large number of samples
LARGE_N = 1000

large_n_data = observed_data(LARGE_N)

fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharex=True, sharey=True)
for ax, (distr_name, data) in zip(axs, large_n_data.items()):
    ax.scatter(data[:, 0], data[:, 1], s=3)
    ax.set_title(f'Distribution: {distr_name}')

# %%
# create fake model output corresponding to the above distributions

GRID_RESOLUTION = 0.1
# everything falls within square [MIN_X, MAX_X] x [MIN_Y, MAX_Y]
xgrid, ygrid = np.meshgrid(
    np.linspace(MIN_X, MAX_X, int((MAX_X - MIN_X)/GRID_RESOLUTION)),
    np.linspace(MIN_Y, MAX_Y, int((MAX_Y - MIN_Y)/GRID_RESOLUTION))
)

n_gridpts = xgrid.shape[0] * xgrid.shape[1]
perfect_uniform_model = np.ones(xgrid.shape) * (1 / n_gridpts)

std_normal_model = scipy.stats.multivariate_normal(
    mean=[0,0], cov=1
    ).pdf(np.dstack((xgrid, ygrid)))

skewed_normal_model = scipy.stats.multivariate_normal(
    mean=[0,0], cov=SKEW_COV
    ).pdf(np.dstack((xgrid, ygrid)))

# and renormalize
std_normal_model /= std_normal_model.sum()
skewed_normal_model /= skewed_normal_model.sum()

models = {
    'uniform': perfect_uniform_model,
    'std_normal': std_normal_model,
    'skew_normal': skewed_normal_model
}

# %%
from mpl_toolkits.axes_grid1 import ImageGrid

fig = plt.figure(figsize=(9, 3))
grid = ImageGrid(fig, 111, # similar to subplot(111)
                 nrows_ncols=(1, 3),
                 axes_pad=0.15,
                 share_all=True,
                 cbar_mode="single",
                 )

for ax, (distr_name, model) in zip(grid, models.items()):
    contour = ax.contourf(xgrid, ygrid, model)
    ax.set_title(f'Model: {distr_name}')

ax.cax.colorbar(contour)

plt.show()

# %% [markdown]
# With our models and data defined, we now examine the calibration curve results for different combinations of the above, still using a large sample size of 1000.

# %%
import collections
import itertools

from common.calibration import calibration_curve
from common.plotting import subplots

def model_calibration_helper(model, data, ax=None, plot=True, x_grid=xgrid, y_grid=ygrid, **kwargs):
    """
    Helper function to automatically calculate and plot calibration curve,
    with prefilled xgrid, ygrid, and n_bins values.
    """
    num_samples = len(data)
    # reshape model to be an array with one pmf for each sample
    reshaped_model = model[np.newaxis, :].repeat(num_samples, axis=0)
    
    bin_edges, true_props = calibration_curve(
        reshaped_model,
        data,
        x_grid,
        y_grid,
        ax=ax,
        plot=plot,
        **kwargs
    )
    
    calibration_err = np.abs(bin_edges - true_props).sum()
    return bin_edges, true_props, calibration_err
    
def calibration_combinations(models: dict, samples: dict, plot=True, **kwargs):
    """
    Calculate the calibration curve and error for every combination
    of the given models and samples.
    
    Args:
        models: dictionary with string keys mapping to np.array values
        samples: same as models.
    """
    errs = collections.defaultdict(dict)
    combinations = list(itertools.product(samples.items(), models.items()))
    fig, axs = [None], [None]
    if plot:
        fig, axs = subplots(len(combinations))
    for ax, combination in itertools.zip_longest(axs, combinations):
        (sample_name, sample), (model_name, model) = combination
        # calculate calibration curve and err
        bin_edges, true_props, err = model_calibration_helper(model, sample, ax=ax, plot=plot, **kwargs)
        # save err
        errs[sample_name][model_name] = err
        if plot:
            ax.set_title(f'model: {model_name} | sample: {sample_name}')
    if plot:
        fig.tight_layout()
        plt.show()
    return errs

# %% [markdown]
# First, look at each model on its corresponding data. Keep track of the error for each model against each set of data in `errs_overall`, where we define the error to be the sum of the residual distances between the plot and the line $ y = x $.

# %%
errs = calibration_combinations(models, large_n_data)

# %% [markdown]
# One important thing to note: on the uniform samples, the models predicting a Gaussian distribution on the space fall far under the expected $y = x$ line. This means that the true proportion of samples inside a region tends to be much lower than the probability the model assigns the region, which makes sense considering that the models are very overconfident.

# %% [markdown]
# Now look into the errors.

# %%
def visualize_calibration_err(overall_err: dict, ax=None):
    """
    Plot a grouped bar chart visualizing calibration error for
    the models and samples.
    """
    # note: assume err dict has the following structure.
    # overall_err
    #    |- data sample 1
    #         |- model 1
    #         |- model 2
    #         |- ...
    #    |- data sample 2
    #         |- ...
    #    |- ...
    
    # the label locations
    x = np.arange(len(overall_err.keys()))
    # the width of the bars
    width = 0.3
    
    ax_provided = ax is not None
    
    if not ax_provided:
        fig, ax = plt.subplots(figsize=(7,7))

    # flip the dict to be broken down by model then by sample
    model_names = list(overall_err.values())[0].keys()
    model_errs_by_sample = {model_name: {} for model_name in model_names}

    for sample_name, errs in overall_err.items():
        for model_name, err in errs.items():
            model_errs_by_sample[model_name][sample_name] = err

    # helper function to calculate bar placement
    offset = lambda idx: (idx - int(len(x) / 2)) * width

    # plot grouped bar chart: grouped by data sample, colored by model
    for i, (model_name, errs) in enumerate(model_errs_by_sample.items()):
        ax.bar(x + offset(i), errs.values(), width, label=f'model: {model_name}')

    ax.set_ylabel('Error vs. perfect calibration')
    ax.set_title('Calibration curve residual errors by model and sample')
    ax.set_xticks(x, [f'data: {k}' for k in overall_err.keys()])
    ax.legend()

    if not ax_provided:
        plt.show()

    return model_errs_by_sample

# %%
large_n_errs_by_sample = visualize_calibration_err(errs)

# %% [markdown]
# ## Fewer samples
# Since we can be reasonably confident that the calibration curve function works, let's now take a look at smaller sample sizes.

# %%
SMALLER_N = 100
smaller_n_data = observed_data(SMALLER_N)

# display data

fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharex=True, sharey=True)
for ax, (distr_name, data) in zip(axs, smaller_n_data.items()):
    ax.scatter(data[:, 0], data[:, 1], s=5)
    ax.set_title(f'Distribution: {distr_name}')

# %% [markdown]
# Seems empirically a little bit noisier than before. Let's take a look at all the combinations.

# %%
smaller_n_errs = calibration_combinations(models, smaller_n_data)

# %% [markdown]
# Still seems reasonable! Take a look at the residual calibration error.

# %%
small_n_errs_by_sample = visualize_calibration_err(smaller_n_errs)

# %% [markdown]
# Looks like the errors are still relatively high for mismatching distributions and they're easily distinguishable. It does seem like errors have increased for matching distributions, though.

# %%
for (model_name, small_n_errs), large_n_errs in zip(small_n_errs_by_sample.items(), large_n_errs_by_sample.values()):
    print(
        f"""
Model: {model_name} | Sample: {model_name}
--------
N = {LARGE_N} error: {large_n_errs[model_name]:.4f}
N = {SMALLER_N} error: {small_n_errs[model_name]:.4f}
        """
    )
# Out:
# Model: uniform | Sample: uniform
# --------
# N = 1000 error: 0.0400
# N = 100 error: 0.1300
#
#
# Model: std_normal | Sample: std_normal
# --------
# N = 1000 error: 0.1120
# N = 100 error: 0.5100
#
#
# Model: skew_normal | Sample: skew_normal
# --------
# N = 1000 error: 0.0720
# N = 100 error: 0.4600

# %% [markdown]
# Looks like that's definitely the case. Now let's try various other `n` values and plot the errors.

# %%
import multiprocessing as mp
from functools import partial

# define function at module level so mp can pickle it
def _calculate_err_mp(queue, sample_fn, models, i, n):
    samples = sample_fn(n)
    err_results = calibration_combinations(models, samples, plot=False, disable_multiprocessing=True)
    for name, err in err_results.items():
        queue.put((name, i, err))

def test_n_values(n_values, samples, models, plot=True):
    errs = {m: np.zeros(len(n_values)) for m in models.keys()}
    m = mp.Manager()
    queue = m.Queue()
    curried = partial(_calculate_err_mp, queue, samples, models)

    with mp.Pool(processes=mp.cpu_count()) as pool:
        pool.starmap(curried, enumerate(n_values))

    while not queue.empty():
        name, idx, err = queue.get()
        errs[name][idx] = err

    if plot:
        fig, axs = subplots(3, 3, figsize=(15, 15), sharex=True, sharey=True)
        for ax, (model, err_line) in zip(axs, errs.items()):
            ax.scatter(n_values, err_line)
            ax.set_xlabel('number of samples')
            ax.set_ylabel('error')
            sample_used = samples_to_use if samples_to_use else model
            ax.set_title(f'model: {model} | sample: {sample_used}')
        fig.suptitle('Effect of varying N on calibration error')
        plt.subplots_adjust(top=0.8)
        plt.show()
    return errs

# %%
n_range = range(50, 1000, 5)

errs = test_n_values(n_range, observed_data, models, plot=False)

# %% [markdown]
# Looks like past around 200 or so, the exact number of samples isn't terribly important for well-calibrated models. We do seem to get noisier results for smaller values of `N`, though. Let's see the effect on incorrect models.

# %%
mismatch_distr_errs = {}
for sample_name in models.keys():
    mismatch_distr_errs[sample_name] = test_n_values(
        n_range,
        observed_data,
        models,
        samples_to_use=sample_name
    )

# %% [markdown]
# Seems like overall, the incorrect distributions have a much higher calibration error, regardless of the number of samples drawn. Encouraging!

# %% [markdown]
# ## Adding noise
# All of the above results are reassuring, but still in an ideal setting. Now add some spherical gaussian noise.

# %%
def display_samples(samples):
    n_distrs = len(samples)
    fig, axs = plt.subplots(1, n_distrs, figsize=(15, 5), sharex=True, sharey=True)
    for ax, (distr_name, data) in zip(axs, samples.items()):
        ax.scatter(data[:, 0], data[:, 1], s=5)
        ax.set_title(f'Distribution: {distr_name}')
    fig.tight_layout()
    plt.show()
    
def full_calibration_breakdown(
    n_samples,
    sampler,
    models,
    add_noise=False,
    noise_std=0.5,
    plot_samples=False,
    plot_calibration=True,
    plot_errs=True
    ):
    samples = sampler(n_samples, add_noise=add_noise, noise_std=noise_std)
    if plot_samples:
        display_samples(samples)
    errs_overall = {}
    for distr_name, model in models.items():
        errs_overall[distr_name] = model_calibration(samples, models, samples_to_use=distr_name, plot=plot_calibration)
    if plot_errs:
        visualize_calibration_err(errs_overall)
    return errs_overall

# %%
err_with_noise = full_calibration_breakdown(LARGE_N, observed_data, models, add_noise=True, plot_samples=True)

# %% [markdown]
# Unfortunately, it seems like adding even a little bit of random noise, specifically $\mathcal{N}(0, 0.5)$, makes it much harder to distinguish the correct model. The calibration error for the spherical model on the standard normal data was about the same as the skew normal model on the same data, which is less than ideal.
#
# Specifically, the calibration curve function appears to prefer *underconfidence*. For example, it seems to severly penalize the standard normal model applied to the noisy normal data, which is higher variance. By contrast, the uniform model's error is far lower even though it's arguably not the best choice of model.
#
# Let's see how this effect changes as we adjust the noise levels.

# %%
from collections import defaultdict

def _calibration_breakdown_mp(n, sampler, models, noise_std):
    errs = full_calibration_breakdown(
        n, sampler, models,
        add_noise=True,
        noise_std=noise_std,
        plot_calibration=False, plot_errs=False
    )
    return (noise_std, errs)

def effects_of_noise_on_calibration(noise_stds, n, sampler, models, plot=True):
    
    curried = partial(_calibration_breakdown_mp, n, sampler, models)
        
    with mp.Pool(processes=mp.cpu_count()) as pool:
        errs_by_std = pool.map(curried, noise_stds)
    
    # next, 'invert' the dict to help make scatterplots of err for each sample
    # and each model
    
    # note: use a defaultdict so that an empty dict is automatically created
    # as the value for each key. it's nested since we have two layers of dicts

    errs_by_sample = defaultdict(lambda: defaultdict(dict))
    for std, err_for_std in errs_by_std:
        for sample, model_errs in err_for_std.items():
            for model, err in model_errs.items():
                errs_by_sample[sample][model][std] = err

    # plot the error, one scatterplot per sample, x axis as noise std
    # y axis as err, color coded by model
    if plot:
        fig, axs = plt.subplots(1, len(models), figsize=(20, 4), sharex=True, sharey=True)

        for (sample, errs_for_sample), ax in zip(errs_by_sample.items(), axs):
            for model_name, errs in errs_for_sample.items():
                stds = list(errs.keys())
                ax.scatter(errs.keys(), errs.values(), marker='o', label=model_name)
                ax.set_xlabel('standard deviation of gaussian noise')
                ax.set_ylabel('calibration error')
                ax.set_title(f'sample: {sample}')
        
        plt.legend()
        plt.show()
    return errs_by_sample

# %%
noise_vals = np.linspace(0, 2, 20)

noise_errs_by_sample = effects_of_noise_on_calibration(
    noise_vals, LARGE_N, observed_data, models
)

# %% [markdown]
# The uniform distribution outperforming the normals makes sense for the higher values of $\sigma$, since that increases spread and pushes the data to look more uniform. Let's take a closer look at smaller values.
#
# Empirically, the standard normal distribution stops having the lowest error on its corresponding data around $\sigma = 0.3$. Let's visualize those few values.

# %%
def plot_std_normal(ax, n, sampler, noise_std):
    data = sampler(n, add_noise=True, noise_std=noise_std)['std_normal']
    ax.plot(data[:, 0], data[:, 1], marker='o', linestyle='None', markersize=2)
    ax.set_title(f'Data for noise std = {noise_std:0.2f}')

std_to_visualize = np.linspace(0.1, 0.5, 5)

fig, axs = plt.subplots(1, 5, figsize=(20, 3), sharex=True, sharey=True)
for std, ax in zip(std_to_visualize, axs):
    plot_std_normal(ax, LARGE_N, observed_data, std)
    ax.contour(xgrid, ygrid, models['std_normal'], zorder=2, linewidths=2)
plt.show()

# %% [markdown]
# Superimposed over the data is the contour plot for the standard normal model. With this visualization, it makes more sense why the normal model starts to do so poorly.
#
# Now let's check the actual error for smaller values of gaussian noise to understand the tolerance we're working with.

# %%
smaller_noise_vals = np.linspace(0, 0.5, 50)

smaller_std_noise_errs = effects_of_noise_on_calibration(
    smaller_noise_vals, LARGE_N, observed_data, models
)

# %% [markdown]
# Looks like for a low variance distribution like the spherical normal, we have a relatively low tolerance for error at around 0.1, before a higher variance model takes over. Fortunately, normal distributions still outperform uniform up until an error of around 0.3. We see somewhat similar results in the skew-normal case, with the uniform only starting to outperform the skew-normal model at around an error of 0.25.
#
# This experiment leads into another question: what happens if the variances of the models don't match the variances of the distributions?

# %% [markdown]
# ## Mismatched Variances
# Test the effects of changing the spherical normal model's variance on it's calibration plots and calibration error.

# %%
# xgrid, ygrid defined above to be on the [-8, 8]^2 square.
def gaussian_w_variance(var):
    model = scipy.stats.multivariate_normal(
        mean=[0,0], cov=var
    ).pdf(np.dstack((xgrid, ygrid)))
    model /= model.sum()
    return model

# %%
from common import plotting

# create a dictionary of models to match the expected argument
# types from `model_calibration`

gaussian_models = lambda variance_list: {v: gaussian_w_variance(v) for v in variance_list}

variances = np.linspace(0.1, 5, 25)

def effect_of_variance(n_samples, data_fn, model_fn, variances, plot=True):
    errs = {}
    fig, axs = plotting.subplots(len(variances))
    idx = 0
    for variance, ax in zip(variances, axs):
        model = model_fn(variance)
        data = data_fn(n_samples)
        bin_edges, true_props, err = model_calibration_helper(
            model,
            data_fn(n_samples),
            x_grid=xgrid,
            y_grid=ygrid,
            ax=ax
        )
        errs[variance] = err
        ax.set_title(f'Model with variance: {variance:0.2f}')
    fig.tight_layout()
    return errs

err_by_variance = effect_of_variance(LARGE_N, lambda n: observed_data(n)['std_normal'], gaussian_w_variance, variances)

# %%
plt.plot(err_by_variance.keys(), err_by_variance.values(), linestyle="None", marker='o', markersize=5)
plt.xlabel('Variance value used in smoothing')
plt.ylabel('Calibration error')
plt.show()

# %% [markdown]
# ## Bin size

# %%
# create fake model output corresponding to the above distributions

# everything falls within square [MIN_X, MAX_X] x [MIN_Y, MAX_Y]
grids = lambda resolution: np.meshgrid(
    np.linspace(MIN_X, MAX_X, int((MAX_X - MIN_X) / resolution)),
    np.linspace(MIN_Y, MAX_Y, int((MAX_Y - MIN_Y) / resolution))
)

def models_by_res(resolution):
    res_xgrid, res_ygrid = grids(resolution)
    
    uniform_model = np.ones(res_xgrid.shape) / res_xgrid.size

    std_normal_model = scipy.stats.multivariate_normal(
        mean=[0,0], cov=1
        ).pdf(np.dstack((res_xgrid, res_ygrid)))

    skewed_normal_model = scipy.stats.multivariate_normal(
        mean=[0,0], cov=SKEW_COV
        ).pdf(np.dstack((res_xgrid, res_ygrid)))

    # and renormalize
    std_normal_model /= std_normal_model.sum()
    skewed_normal_model /= skewed_normal_model.sum()

    models = {
        'uniform': uniform_model,
        'std_normal': std_normal_model,
        'skew_normal': skewed_normal_model
    }
    return models

# %%
smaller_n_data['uniform'].shape
# Out:
# (100, 2)

# %%
import functools
import multiprocessing as mp

resolutions = np.linspace(0.1, 0.5, 100)

def to_map(r):
    xgrid, ygrid = grids(r)
    return calibration_combinations(models_by_res(r), smaller_n_data, x_grid=xgrid, y_grid=ygrid, disable_multiprocessing=True, plot=False)

with mp.Pool() as pool:
    errs = pool.map(to_map, resolutions)

# %%
from common import plotting
fig, axs = plotting.subplots(len(errs), scale_factor=5, sharex=False)

for ax, err, res in zip(axs, errs, resolutions):
    visualize_calibration_err(err, ax=ax)
    ax.set_title(f'resolution: {res:0.2f}')

fig.tight_layout()
plt.show()

# %% [markdown]
# ### Examine different smoothing methods on newly generated data
# The underlying data was Aramis's `iteration/split_twelve_raw/train_set.h5` file, which contains pyroomacoustics fake data generated on a room of shape 1.83 by 2.44 by 0.76 (m).

# %%
# MUSE output evaluated on the above dataset (run with resolution = 0.001 m)
PREDICTIONS = Path.home() / 'ceph' / 'np_arrays' / 'split_twelve_raw' / 'train_set_muse_preds.h5'
LOCATIONS = Path('/mnt/ceph/users/atanelus/iteration/split_twelve_raw/train_set.h5')

RESOLUTION_USED = 0.001

# %%
locs = h5py.File(LOCATIONS, 'r')['locations']

# %%
locs
# Out:
# <HDF5 dataset "locations": shape (16000, 2), type "<f4">

# %%
import h5py
preds = h5py.File(PREDICTIONS, 'r')

# shape sanity check
print(preds['r_ests'])
print(preds['rsrp_grids'])
# Out:
# <HDF5 dataset "r_ests": shape (16000, 4, 2), type "<f8">
# <HDF5 dataset "rsrp_grids": shape (16000, 1830, 2440), type "<f8">

# %%
xdim, ydim = LARGE_ROOM_DIMS[1:]
xs = np.linspace(0, xdim, int(xdim / RESOLUTION_USED))
ys = np.linspace(0, ydim, int(ydim / RESOLUTION_USED))

xgrid, ygrid = np.meshgrid(xs, ys)

# %%
class SmoothingFunctions:
    def __init__(xgrid, ygrid, r_ests_arr, rsrp_grids_arr):
        # self.r_ests = np.array(r_ests_arr)
        # self.rsrp_grids = np.array(rsrp_grids_arr)
        self.xgrid = xgrid
        self.ygrid = ygrid
    
    def simple_softmax(self, combine_method='avg'):
        """Naively apply a softmax to the RSRP grids to convert them into probability maps."""
        ## TODO swap order of avg and softmaxing

        # combine the grids from each point estimate
        if combine_method == 'avg':
            combined = self.rsrp_grids.mean(axis=1)
        elif combine_method == 'sum':
            combined = self.rsrp_grids.sum(axis=1)
        # normalize them so we don't get crazy infinity values from exponentiation step of softmax
        max_val = combined.max(axis=0)
        combined /= max_val
        # then apply softmax
        softmaxed = np.exp(combined) / np.exp(combined).sum(axis=(1, 2))
        return self.xgrid, self.ygrid, softmaxed
    
    def gaussian_at_each_jackknife(self, sigma=1, larger_bins=True):
        """
        Place a spherical gaussian of variance sigma at each jackknife estimate,
        renormalize, and return.
        """
        # decrease the resolution of the bins by a factor of 10 or so
        # to save memory
        xgrid, ygrid = self.xgrid, self.ygrid
        if larger_bins:
            xgrid = self.xgrid[::10, ::10]
            ygrid = self.ygrid[::10, ::10]
        results = np.zeros((len(r_ests_arr), xgrid.shape[0], xgrid.shape[1]))
        n_mics = self.r_ests.shape[1]
        for i, point_ests in enumerate(self.r_ests):
            # create n_mics normal distributions, each centered at one point estimate
            # and with mean sigma
            distrs = scipy.stats.norm(point_ests, [sigma] * n_mics)
            # evaluate each distribution at each point on the grid
            pmfs = distrs.pdf(np.dstack(xgrid, ygrid)[np.newaxis, :].repeat(n_mics, axis=0))
            # average the results to get one distribution
            results[i] = pmfs.mean(axis=0)
        return xgrid, ygrid, results        
            
    def convolve_gaussian(self, sigma=0.5, renormalize=True):
        """Convolve a spherical gaussian kernel of variance sigma over each map."""
        # TODO: make argument the pixel width of the filter,
        # not sigma
    
        # first renormalize just in case
        grids = self.rsrp_grids
        if renormalize:
            grids /= self.rsrp_grids.max(axis=0)
        for i, g in enumerate(grids):
            grids[i] = scipy.ndimage_gaussian_filter(g, sigma=sigma)
        # lastly, apply softmax
        grids = np.exp(grids) / np.exp(grids).sum(axis=(1, 2))
        return self.xgrid, self.ygrid, grids

    def perfect_uniform(self, larger_bins=False):
        xgrid, ygrid = self.xgrid, self.ygrid
        if larger_bins:
            xgrid = self.xgrid[::10][::10]
            ygrid = self.ygrid[::10][::10]
        
        num_pts = xgrid.shape[1] * xgrid.shape[2]
        uniform = np.ones(shape) / num_pts
        return xgrid, ygrid, uniform
    
    # def uniform_with_peak():
    #     pass

def examine_calibration(xgrid, ygrid, results):
    common.calibration.plot_calibration_curve(
        results,
        locs,
        xgrid,
        ygrid
    )

# %%
small_subset_smoothing = SmoothingFunctions(
    xgrid,
    ygrid,
    preds['r_ests'][:1000],
    preds['rsrp_grids'][:1000]
)
